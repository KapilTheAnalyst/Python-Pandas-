# %% [markdown]
# Indexing in Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Different_Types_of_Files\world_population.csv")
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
# Setting index to a country
df = pd.read_csv(r"C:\Different_Types_of_Files\world_population.csv", index_col = 'Country/Territory')
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country/Territory
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH          El Aaiún    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
# reversing index 

df.reset_index(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4264\629543277.py in ?()
#       1 # reversing index
#       2
# ----> 3 df.reset_index(inplace = True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
# ...

# %%
df
# Out:
#      level_0  index  Country/Territory  Rank CCA3           Capital Continent  \
# 0          0      0        Afghanistan    36  AFG             Kabul      Asia
# 1          1      1            Albania   138  ALB            Tirana    Europe
# 2          2      2            Algeria    34  DZA           Algiers    Africa
# 3          3      3     American Samoa   213  ASM         Pago Pago   Oceania
# 4          4      4            Andorra   203  AND  Andorra la Vella    Europe
# ..       ...    ...                ...   ...  ...               ...       ...
# 229      229    229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230      230    230     Western Sahara   172  ESH          El Aaiún    Africa
# 231      231    231              Yemen    46  YEM             Sanaa      Asia
# 232      232    232             Zambia    63  ZMB            Lusaka    Africa
# 233      233    233           Zimbabwe    74  ZWE            Harare    Africa
#
# ...

# %%
df.set_index('Country/Territory')
# Out:
#                    level_0  index  Rank CCA3           Capital Continent  \
# Country/Territory
# Afghanistan              0      0    36  AFG             Kabul      Asia
# Albania                  1      1   138  ALB            Tirana    Europe
# Algeria                  2      2    34  DZA           Algiers    Africa
# American Samoa           3      3   213  ASM         Pago Pago   Oceania
# Andorra                  4      4   203  AND  Andorra la Vella    Europe
# ...                    ...    ...   ...  ...               ...       ...
# Wallis and Futuna      229    229   226  WLF          Mata-Utu   Oceania
# Western Sahara         230    230   172  ESH          El Aaiún    Africa
# Yemen                  231    231    46  YEM             Sanaa      Asia
# Zambia                 232    232    63  ZMB            Lusaka    Africa
# Zimbabwe               233    233    74  ZWE            Harare    Africa
#
#                    2022 Population  2020 Population  2015 Population  \
# ...

# %%
df = df.drop('level_0', axis = 1)

# %%
df
# Out:
#      index  Country/Territory  Rank CCA3           Capital Continent  \
# 0        0        Afghanistan    36  AFG             Kabul      Asia
# 1        1            Albania   138  ALB            Tirana    Europe
# 2        2            Algeria    34  DZA           Algiers    Africa
# 3        3     American Samoa   213  ASM         Pago Pago   Oceania
# 4        4            Andorra   203  AND  Andorra la Vella    Europe
# ..     ...                ...   ...  ...               ...       ...
# 229    229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230    230     Western Sahara   172  ESH          El Aaiún    Africa
# 231    231              Yemen    46  YEM             Sanaa      Asia
# 232    232             Zambia    63  ZMB            Lusaka    Africa
# 233    233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
df = df.drop('index' , axis = 1)

# %%
df
# Out:
#      Country/Territory  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.set_index('Country/Territory', inplace=True)
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country/Territory
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH          El Aaiún    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df.loc['Albania']
# Out:
# Rank                               138
# CCA3                               ALB
# Capital                         Tirana
# Continent                       Europe
# 2022 Population                2842321
# 2020 Population                2866849
# 2015 Population                2882481
# 2010 Population                2913399
# 2000 Population                3182021
# 1990 Population                3295066
# 1980 Population                2941651
# 1970 Population                2324731
# Area (km²)                       28748
# Density (per km²)              98.8702
# Growth Rate                     0.9957
# World Population Percentage       0.04
# Name: Albania, dtype: object

# %%
df.iloc[1]
# Out:
# Rank                               138
# CCA3                               ALB
# Capital                         Tirana
# Continent                       Europe
# 2022 Population                2842321
# 2020 Population                2866849
# 2015 Population                2882481
# 2010 Population                2913399
# 2000 Population                3182021
# 1990 Population                3295066
# 1980 Population                2941651
# 1970 Population                2324731
# Area (km²)                       28748
# Density (per km²)              98.8702
# Growth Rate                     0.9957
# World Population Percentage       0.04
# Name: Albania, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      Country/Territory  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.set_index(['Continent','Country/Territory' ] ,inplace= True)

# %%
df
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country/Territory
# Asia      Afghanistan          36  AFG             Kabul         41128771
# Europe    Albania             138  ALB            Tirana          2842321
# Africa    Algeria              34  DZA           Algiers         44903225
# Oceania   American Samoa      213  ASM         Pago Pago            44273
# Europe    Andorra             203  AND  Andorra la Vella            79824
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu            11572
# Africa    Western Sahara      172  ESH          El Aaiún           575986
# Asia      Yemen                46  YEM             Sanaa         33696614
# Africa    Zambia               63  ZMB            Lusaka         20017675
#           Zimbabwe             74  ZWE            Harare         16320537
#
# ...

# %%
df.sort_index()
# Out:
#                                  Rank CCA3      Capital  2022 Population  \
# Continent     Country/Territory
# Africa        Algeria              34  DZA      Algiers         44903225
#               Angola               42  AGO       Luanda         35588987
#               Benin                77  BEN   Porto-Novo         13352864
#               Botswana            144  BWA     Gaborone          2630296
#               Burkina Faso         58  BFA  Ouagadougou         22673762
# ...                               ...  ...          ...              ...
# South America Paraguay            109  PRY     Asunción          6780744
#               Peru                 44  PER         Lima         34049588
#               Suriname            170  SUR   Paramaribo           618040
#               Uruguay             133  URY   Montevideo          3422794
#               Venezuela            51  VEN      Caracas         28301696
#
# ...

# %%
df.sort_index(ascending = False)
# Out:
#                                  Rank CCA3      Capital  2022 Population  \
# Continent     Country/Territory
# South America Venezuela            51  VEN      Caracas         28301696
#               Uruguay             133  URY   Montevideo          3422794
#               Suriname            170  SUR   Paramaribo           618040
#               Peru                 44  PER         Lima         34049588
#               Paraguay            109  PRY     Asunción          6780744
# ...                               ...  ...          ...              ...
# Africa        Burkina Faso         58  BFA  Ouagadougou         22673762
#               Botswana            144  BWA     Gaborone          2630296
#               Benin                77  BEN   Porto-Novo         13352864
#               Angola               42  AGO       Luanda         35588987
#               Algeria              34  DZA      Algiers         44903225
#
# ...

# %%
df.loc['Africa','Angola']
# Out:
# Rank                                 42
# CCA3                                AGO
# Capital                          Luanda
# 2022 Population                35588987
# 2020 Population                33428485
# 2015 Population                28127721
# 2010 Population                23364185
# 2000 Population                16394062
# 1990 Population                11828638
# 1980 Population                 8330047
# 1970 Population                 6029700
# Area (km²)                      1246700
# Density (per km²)               28.5466
# Growth Rate                      1.0315
# World Population Percentage        0.45
# Name: (Africa, Angola), dtype: object

# %%
df.iloc[1]
# Out:
# Rank                               138
# CCA3                               ALB
# Capital                         Tirana
# 2022 Population                2842321
# 2020 Population                2866849
# 2015 Population                2882481
# 2010 Population                2913399
# 2000 Population                3182021
# 1990 Population                3295066
# 1980 Population                2941651
# 1970 Population                2324731
# Area (km²)                       28748
# Density (per km²)              98.8702
# Growth Rate                     0.9957
# World Population Percentage       0.04
# Name: (Europe, Albania), dtype: object

# %%
df
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country/Territory
# Asia      Afghanistan          36  AFG             Kabul         41128771
# Europe    Albania             138  ALB            Tirana          2842321
# Africa    Algeria              34  DZA           Algiers         44903225
# Oceania   American Samoa      213  ASM         Pago Pago            44273
# Europe    Andorra             203  AND  Andorra la Vella            79824
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu            11572
# Africa    Western Sahara      172  ESH          El Aaiún           575986
# Asia      Yemen                46  YEM             Sanaa         33696614
# Africa    Zambia               63  ZMB            Lusaka         20017675
#           Zimbabwe             74  ZWE            Harare         16320537
#
# ...

# %%
df =df.sort_index(ascending = True)

# %%
df
# Out:
#                                  Rank CCA3      Capital  2022 Population  \
# Continent     Country/Territory
# Africa        Algeria              34  DZA      Algiers         44903225
#               Angola               42  AGO       Luanda         35588987
#               Benin                77  BEN   Porto-Novo         13352864
#               Botswana            144  BWA     Gaborone          2630296
#               Burkina Faso         58  BFA  Ouagadougou         22673762
# ...                               ...  ...          ...              ...
# South America Paraguay            109  PRY     Asunción          6780744
#               Peru                 44  PER         Lima         34049588
#               Suriname            170  SUR   Paramaribo           618040
#               Uruguay             133  URY   Montevideo          3422794
#               Venezuela            51  VEN      Caracas         28301696
#
# ...
